# %% [markdown]
# # Phase 1 Pilot Study Notebook
#
# This notebook runs the Phase 1 workflow from the existing Python pipeline and can resume from saved checkpoints instead of restarting from scratch.

# %%
# !python phase1_complexity_aware.py
